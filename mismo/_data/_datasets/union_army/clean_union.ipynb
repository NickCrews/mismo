# %% [markdown]
# Cleans the raw union army data from NBER into a format
# for mismo that minimizes the boilerplate that users will need.

# %%
import ibis
from ibis import _

ibis.options.interactive = True

cen_path_in = "../../../../.scratch/union_army/CEN.csv"
msr_path_in = "../../../../.scratch/union_army/MSR.csv"
cen = ibis.read_csv(cen_path_in)
msr = ibis.read_csv(msr_path_in)
cen
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ record_id ┃ last_name ┃ first_name ┃ middle_name ┃ birth_year ┃ birth_month ┃ gender ┃ birth_place ┃ label_true ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ int64     │ string    │ string     │ string      │ string     │ string      │ string │ string      │ string     │
# ├───────────┼───────────┼────────────┼─────────────┼────────────┼─────────────┼────────┼─────────────┼────────────┤
# │         0 │ ALKESKEY  │ THEODORE   │ F           │ 1840       │ 03          │ M      │ NY          │ 0100501002 │
# │         1 │ BRADLEY   │ GEORGE     │ A           │ 1847       │ 06          │ M      │ CT          │ 0100501004 │
# │         2 │ BURRITT   │ WM         │ NULL        │ 1847       │ 11          │ M      │ CT          │ 0100501005 │
# │         3 │ BOOTH     │ FREDRICK   │ J           │ 1842       │ 06          │ M      │ CT          │ 0100501007 │
# │         4 │ BEERS     │ WILLIAM    │ E           │ 1839       │ 02          │ M      │ CT          │ 0100501009 │
# │         5 │ BENEDICT  │ THOMAS     │ NULL        │ 1841       │ 02          │ M      │ CT          │ 0100501010 │
# │         6 │ COLE      │ HIRAM      │ M           │ 1843       │ 01          │ M      │ CT          │ 0100501018 │
# │         7 │ CURTISS   │ HENRY      │ B           │ 1840       │ 09          │ M      │ CT          │ 0100501019 │
# │         8 │ CARNEY    │ JOHN       │ NULL        │ 1844       │ 03          │ M      │ IR          │ 0100501020 │
# │         9 │ COMSTOCK  │ DAVID      │ O           │ 1841       │ 02          │ M      │ CT          │ 0100501021 │
# │         … │ …         │ …          │ …           │ …          │ …           │ …      │ …           │ …          │
# └───────────┴───────────┴────────────┴─────────────┴────────────┴─────────────┴────────┴─────────────┴────────────┘

# %%
cen = cen.select(
    "record_id",
    _.label_true.cast("int64").name("label_true"),
    first_name=_.first_name.strip(),
    middle_name=_.middle_name.strip(),
    last_name=_.last_name.strip(),
    birth_year=_.birth_year.strip(),
    birth_month=_.birth_month.strip(),
    birth_place=_.birth_place.strip(),
    gender=_.gender.strip(),
)
cen
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ record_id ┃ label_true ┃ first_name ┃ middle_name ┃ last_name ┃ birth_year ┃ birth_month ┃ birth_place ┃ gender ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━┩
# │ int64     │ int64      │ string     │ string      │ string    │ string     │ string      │ string      │ string │
# ├───────────┼────────────┼────────────┼─────────────┼───────────┼────────────┼─────────────┼─────────────┼────────┤
# │         0 │  100501002 │ THEODORE   │ F           │ ALKESKEY  │ 1840       │ 03          │ NY          │ M      │
# │         1 │  100501004 │ GEORGE     │ A           │ BRADLEY   │ 1847       │ 06          │ CT          │ M      │
# │         2 │  100501005 │ WM         │ NULL        │ BURRITT   │ 1847       │ 11          │ CT          │ M      │
# │         3 │  100501007 │ FREDRICK   │ J           │ BOOTH     │ 1842       │ 06          │ CT          │ M      │
# │         4 │  100501009 │ WILLIAM    │ E           │ BEERS     │ 1839       │ 02          │ CT          │ M      │
# │         5 │  100501010 │ THOMAS     │ NULL        │ BENEDICT  │ 1841       │ 02          │ CT          │ M      │
# │         6 │  100501018 │ HIRAM      │ M           │ COLE      │ 1843       │ 01          │ CT          │ M      │
# │         7 │  100501019 │ HENRY      │ B           │ CURTISS   │ 1840       │ 09          │ CT          │ M      │
# │         8 │  100501020 │ JOHN       │ NULL        │ CARNEY    │ 1844       │ 03          │ IR          │ M      │
# │         9 │  100501021 │ DAVID      │ O           │ COMSTOCK  │ 1841       │ 02          │ CT          │ M      │
# │         … │          … │ …          │ …           │ …         │ …          │ …           │ …           │ …      │
# └───────────┴────────────┴────────────┴─────────────┴───────────┴────────────┴─────────────┴─────────────┴────────┘

# %%
def fix_month(m):
    # We only fix unambiguous months. We leave eg "99" as is
    mapping = {
        "JAN": "01",
        "FEB": "02",
        "MAR": "03",
        "APR": "04",
        "MAY": "05",
        "JUN": "06",
        "JUL": "07",
        "AUG": "08",
        "SEP": "09",
        "OCT": "10",
        "NOV": "11",
        "DEC": "12",
        # We only fix unambiguous months. We leave eg "99" as is
        # "UNK": "--",
        # "UN": "--",
        # "99": "--",
        # "999": "--",
    }
    return m.substitute(mapping).nullif("--")


cen = cen.mutate(birth_month=fix_month(cen.birth_month))
cen.birth_month.topk(40).execute()
# Out:
#    birth_month  Count(birth_month)
# 0           03                5139
# 1           05                4803
# 2           10                4646
# 3           08                4640
# 4           04                4620
# 5           02                4566
# 6           09                4499
# 7           01                4453
# 8           06                4359
# 9           12                4250
# 10          07                4209
# 11          11                4102
# 12         999                  36
# 13          ?R                  36
# 14          UN                  11
# 15          99                   8
# 16         UNK                   3
# 17          JU                   2
# 18         (IL                   2
# 19        None                   0

# %%
cen[_.birth_year.length() != 4]
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ record_id ┃ label_true ┃ first_name ┃ middle_name ┃ last_name ┃ birth_year ┃ birth_month ┃ birth_place ┃ gender ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━┩
# │ int64     │ int64      │ string     │ string      │ string    │ string     │ string      │ string      │ string │
# ├───────────┼────────────┼────────────┼─────────────┼───────────┼────────────┼─────────────┼─────────────┼────────┤
# │      1259 │ 1304101049 │ HENRY      │ NULL        │ MOLDT     │ ?K         │ NULL        │ GE          │ M      │
# │      1340 │ 1304807075 │ ABRAM      │ M           │ ROSE      │ ?K         │ 08          │ NY          │ M      │
# │      2453 │ 1313609037 │ HENRY      │ NULL        │ HAVENS    │ ?R         │ 03          │ NULL        │ M      │
# │      5711 │ 2202403063 │ HARRY      │ G           │ LAZARUS   │ UN         │ UN          │ FR          │ M      │
# │      5920 │ 2203502072 │ LAWRENCE   │ NULL        │ SHERIDAN  │ UN         │ UN          │ IR          │ M      │
# │      9252 │ 2414502012 │ HENRY      │ NULL        │ COLLINS   │ ?R         │ ?R          │ NULL        │ M      │
# │     10029 │ 2501809111 │ PATRICK    │ NULL        │ STINSON   │ UN         │ UN          │ IR          │ M      │
# │     13993 │       NULL │ IDA        │ NULL        │ LOFLAND   │ ?K         │ 999         │ DE          │ F      │
# │     14264 │       NULL │ ELIZABETH  │ NULL        │ MOLDT     │ ?K         │ NULL        │ PA          │ F      │
# │     14715 │       NULL │ SARAH      │ NULL        │ RYLANDS   │ ?          │ ?R          │ NY          │ F      │
# │         … │          … │ …          │ …           │ …         │ …          │ …           │ …           │ …      │
# └───────────┴────────────┴────────────┴─────────────┴───────────┴────────────┴─────────────┴─────────────┴────────┘

# %%
msr = msr.select(
    record_id=_.record_id,
    label_true=_.label_true,
    first_name=_.first_name.strip(),
    middle_name=_.middle_name.strip(),
    last_name=_.last_name.strip(),
    birth_date=_.birth_date.strip(),
    birth_place=_.birth_place,
    enlist_date=_.enlistment_date,
    enlist_age=_.enlistment_age,
)
msr
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ record_id ┃ label_true ┃ first_name ┃ middle_name ┃ last_name  ┃ birth_date ┃ birth_place ┃ enlist_date ┃ enlist_age ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ int64     │ int64      │ string     │ string      │ string     │ string     │ string      │ string      │ int64      │
# ├───────────┼────────────┼────────────┼─────────────┼────────────┼────────────┼─────────────┼─────────────┼────────────┤
# │         0 │  100501001 │ CHARLES    │ H           │ ANSON      │ NULL       │ EN          │ 18610722    │         29 │
# │         1 │  100501002 │ THEODORE   │ F           │ ALLSHESKEY │ NULL       │ NY          │ 18610722    │         21 │
# │         2 │  100501003 │ CHARLES    │ W           │ BILL       │ NULL       │ CT          │ 18610722    │         25 │
# │         3 │  100501004 │ GEORGE     │ A           │ BRADLEY    │ NULL       │ CT          │ 18610722    │         18 │
# │         4 │  100501005 │ WILLIAM    │ N           │ BUNITT     │ NULL       │ CT          │ 18610722    │         18 │
# │         5 │  100501007 │ FREDERICK  │ J           │ BOOTH      │ NULL       │ CT          │ 18610722    │         19 │
# │         6 │  100501008 │ JAMES      │ NULL        │ BYERS      │ NULL       │ IR          │ 18610722    │         35 │
# │         7 │  100501009 │ WILLIAM    │ E           │ BEERS      │ NULL       │ CT          │ 18610722    │         22 │
# │         8 │  100501010 │ THOMAS     │ E           │ BENEDICT   │ NULL       │ CT          │ 18610722    │         21 │
# │         9 │  100501011 │ THEODORE   │ D           │ CLARK      │ NULL       │ CT          │ 18610722    │         18 │
# │         … │          … │ …          │ …           │ …          │ …          │ …           │ …           │          … │
# └───────────┴────────────┴────────────┴─────────────┴────────────┴────────────┴─────────────┴─────────────┴────────────┘

# %%
msr.enlist_age.topk(100).execute()
# Out:
#     enlist_age  Count(enlist_age)
# 0         18.0               5668
# 1         19.0               3251
# 2         21.0               3063
# 3         20.0               2655
# 4         22.0               2405
# ..         ...                ...
# 57        67.0                  1
# 58        72.0                  1
# 59        64.0                  1
# 60        61.0                  1
# 61         NaN                  0
#
# [62 rows x 2 columns]

# %%
# Some dates in MSR are in MMDDYYYY format


def is_not_YYYYMMDD(date):
    return ~date[:2].isin(["18", "--"])


def fix_MMDDYYYY(date):
    bad = is_not_YYYYMMDD(date)
    fixed = date[4:8] + date[:2] + date[2:4]
    return bad.ifelse(fixed, date)


print(is_not_YYYYMMDD(msr.enlist_date).value_counts())
display(msr[is_not_YYYYMMDD(_.enlist_date)])
msr = msr.mutate(enlist_date=fix_MMDDYYYY(_.enlist_date))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Not(InValues(Substring(enlist_date, 0, 2))) ┃ Not(InValues(Substring(enlist_date, 0, 2)))_count ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ boolean                                     │ int64                                             │
# ├─────────────────────────────────────────────┼───────────────────────────────────────────────────┤
# │ True                                        │                                                25 │
# │ False                                       │                                             39279 │
# │ NULL                                        │                                                36 │
# └─────────────────────────────────────────────┴───────────────────────────────────────────────────┘
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ record_id ┃ label_true ┃ first_name ┃ middle_name ┃ last_name ┃ birth_date ┃ birth_place ┃ enlist_date ┃ enlist_age ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ int64     │ int64      │ string     │ string      │ string    │ string     │ string      │ string      │ int64      │
# ├───────────┼────────────┼────────────┼─────────────┼───────────┼────────────┼─────────────┼─────────────┼────────────┤
# │     19479 │ 2202202138 │ WILLIAM    │ NULL        │ DAHLBY    │ NULL       │ NULL        │ 08051862    │         20 │
# │     19626 │ 2202309133 │ JAMES      │ NULL        │ RIDD      │ NULL       │ NULL        │ 12141863    │         27 │
# │     19861 │ 2202403214 │ DANIEL     │ O           │ LOUGHELIN │ NULL       │ NULL        │ 09201864    │         21 │
# │     19868 │ 2202607002 │ CLARK      │ NULL        │ ETHER     │ NULL       │ NULL        │ 07271861    │         30 │
# │     19906 │ 2202607040 │ WILLIAM    │ H           │ FINKLE    │ NULL       │ NULL        │ 07271861    │         18 │
# │     19907 │ 2202607041 │ JONATHAN   │ NULL        │ FISH      │ NULL       │ NULL        │ 07271861    │         21 │
# │     19982 │ 2202607116 │ JOHN       │ W           │ NISLY     │ NULL       │ NULL        │ 03031864    │         21 │
# │     19997 │ 2202607131 │ WILLIAM    │ H           │ JONES     │ NULL       │ NULL        │ 11261864    │         22 │
# │     20515 │ 2203703167 │ ROBERT     │ S           │ WARD      │ NULL       │ NULL        │ 10131864    │         19 │
# │     20702 │ 2204205164 │ N          │ NULL        │ VA        │ NULL       │ NULL        │ 11221864    │         27 │
# │         … │          … │ …          │ …           │ …         │ …          │ …           │ …           │          … │
# └───────────┴────────────┴────────────┴─────────────┴───────────┴────────────┴─────────────┴─────────────┴────────────┘

# %%
# Verify integrity


def is_unique(vals):
    counts = vals.name("val").value_counts()
    nonnull = counts[_.val.notnull()]
    return (nonnull.val_count == 1).all().execute()


assert is_unique(msr.record_id)
assert is_unique(cen.record_id)
assert is_unique(msr.label_true)
assert is_unique(cen.label_true)

assert msr.label_true.isnull().sum().execute() == 0
assert cen.label_true.isnull().sum().execute() > 0

assert cen.gender.isnull().sum().execute() > 0
assert cen.gender.isin(["M", "F", "("]).all().execute()

# Dubious enlist age
assert msr.enlist_age.min().execute() == 2
assert msr.enlist_age.max().execute() >= 70

# %%
msr_path_out = "./MSR.csv"
cen_path_out = "./CEN.csv"
msr.to_csv(msr_path_out)
cen.to_csv(cen_path_out)
